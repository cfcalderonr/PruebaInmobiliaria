# %% [markdown]
# # Prueba de conocimientos

# %% [markdown]
# ## Paquetes

# %%
import pandas as pd
import geoplot.crs as gcrs
import geoplot as gplt
import geopandas as gpd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Cargue de datos

# %%
df = pd.read_csv(r'..\input\house_data.csv')
df.shape
# Out:
# (21613, 21)

# %%
seattle = gpd.read_file("..\input\maps\kc_block_10.shp")
seattle.head()
# Out:
#    OBJECTID STATEFP10 COUNTYFP10 TRACTCE10 BLOCKCE10          GEOID10  \
# 0         1        53        033    006700      1001  530330067001001
# 1         2        53        033    006900      1009  530330069001009
# 2         3        53        033    011600      3013  530330116003013
# 3         4        53        033    011600      5021  530330116005021
# 4         5        53        033    011600      5023  530330116005023
#
#        NAME10 MTFCC10  UR10 UACE10 FUNCSTAT10   ALAND10  AWATER10  \
# 0  Block 1001   G5040  None   None          S  121128.0       0.0
# 1  Block 1009   G5040  None   None          S   20412.0       0.0
# 2  Block 3013   G5040  None   None          S   23687.0       0.0
# 3  Block 5021   G5040  None   None          S   16082.0       0.0
# 4  Block 5023   G5040  None   None          S    2697.0       0.0
#
#     INTPTLAT10    INTPTLON10  TRACT_10  Shape_Leng    Shape_Area        TRBL  \
# 0  +47.6319178  -122.3399002      6700    0.027448  1.449595e-05   6700.1001
# 1  +47.6368455  -122.3629779      6900    0.006327  2.443019e-06   6900.1009
# 2  +47.5235687  -122.3857630     11600    0.008314  2.828987e-06  11600.3013
# 3  +47.5204486  -122.3920438     11600    0.005893  1.920568e-06  11600.5021
# 4  +47.5205365  -122.3899013     11600    0.003135  3.220622e-07  11600.5023
#
#                                             geometry
# 0  POLYGON ((-122.34063 47.63249, -122.34034 47.6...
# 1  POLYGON ((-122.36232 47.63593, -122.36366 47.6...
# 2  POLYGON ((-122.38455 47.52419, -122.38456 47.5...
# 3  POLYGON ((-122.39178 47.51974, -122.39256 47.5...
# 4  POLYGON ((-122.39022 47.52080, -122.38939 47.5...

# %%
continental_usa_cities = gpd.read_file(gplt.datasets.get_path('usa_cities'))
continental_usa_cities = continental_usa_cities.query('STATE in ["WA"]')
contiguous_usa = gpd.read_file(gplt.datasets.get_path('usa_cities'))

# %%
ax = gplt.webmap(contiguous_usa, projection=gcrs.WebMercator())
gplt.pointplot(continental_usa_cities, ax=ax)
# Out:
# <GeoAxesSubplot:>

# %%
contiguous_usa.head()
contiguous_usa.head()
# Out:
#           state adm1_code  population  \
# 0     Minnesota  USA-3514     5303925
# 1       Montana  USA-3515      989415
# 2  North Dakota  USA-3516      672591
# 3         Idaho  USA-3518     1567582
# 4    Washington  USA-3519     6724540
#
#                                             geometry
# 0  POLYGON ((-89.59941 48.01027, -89.48888 48.013...
# 1  POLYGON ((-111.19419 44.56116, -111.29155 44.7...
# 2  POLYGON ((-96.60136 46.35136, -96.53891 46.199...
# 3  POLYGON ((-111.04973 44.48816, -111.05025 42.0...
# 4  POLYGON ((-116.99807 46.33017, -116.90653 46.1...

# %%
viviendas = df[['id','lat','long']]
# viviendas.assign(geometry = lambda dataframe: dataframe['age'].map(lambda age: True if age >= 65 else False) )
viviendas = viviendas.assign(STATE = 'WA')
viviendas['long'] = viviendas['long'].astype(str)
viviendas['lat'] = viviendas['lat'].astype(str)
viviendas = viviendas.assign(geometry = 'POINT(' + viviendas['long'] + ' ' + viviendas['lat'] + ')')
gplt.pointplot(viviendas, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 7>()
#       5 viviendas['lat'] = viviendas['lat'].astype(str)
#       6 viviendas = viviendas.assign(geometry = 'POINT(' + viviendas['long'] + ' ' + viviendas['lat'] + ')')
# ----> 7 gplt.pointplot(viviendas, ax=ax)
#
# File ~\anaconda3\envs\PruebaInmobiliaria\lib\site-packages\geoplot\geoplot.py:821, in pointplot(df, projection, hue, cmap, norm, scheme, scale, limits, scale_func, legend, legend_var, legend_values, legend_labels, legend_kwargs, figsize, extent, ax, **kwargs)
#     818             ax.scatter(xs, ys, c=plot.colors, s=[s**2 for s in plot.sizes], **plot.kwargs)
#     819         return ax
# --> 821 plot = PointPlot(
#     822     df, figsize=figsize, ax=ax, extent=extent, projection=projection,
#     823     hue=hue, scheme=scheme, cmap=cmap, norm=norm,
#     824     scale=scale, limits=limits, scale_func=scale_func,
#     825     legend=legend, legend_var=legend_var, legend_values=legend_values,
#     826     legend_labels=legend_labels, legend_kwargs=legend_kwargs,
#     827     **kwargs
#     828 )
#     829 return plot.draw()
#
# File ~\anaconda3\envs\PruebaInmobiliaria\lib\site-packages\geoplot\geoplot.py:796, in pointplot.<locals>.PointPlot.__init__(self, df, **kwargs)
#     795 def __init__(self, df, **kwargs):
# --> 796     super().__init__(df, **kwargs)
#     797     self.set_hue_values(color_kwarg='color', default_color='steelblue')
#     798     self.set_scale_values(size_kwarg='s', default_size=5)
#
# File ~\anaconda3\envs\PruebaInmobiliaria\lib\site-packages\geoplot\geoplot.py:628, in Plot.__init__(self, df, **kwargs)
#     626 self.projection = kwargs.pop('projection')
#     627 # TODO: init_axes() -> init_axes(ax)
# --> 628 self.init_axes()
#     629 self.kwargs = kwargs
#
# File ~\anaconda3\envs\PruebaInmobiliaria\lib\site-packages\geoplot\geoplot.py:639, in Plot.init_axes(self)
#     637     extrema = np.array([0, 0, 1, 1])  # default Matplotlib plot extent
#     638 else:
# --> 639     xmin, ymin, xmax, ymax = self.df.total_bounds
#     640     # Plots suffer clipping issues if we use just the geometry extrema due to plot features
#     641     # that fall outside of the viewport. The most common case is the edges of polygon
#     642     # patches with non-zero linewidth. We partially ameliorate the problem by increasing
#    (...)
#     645     # degrees varies depending on where you are on the globe. Since the effect is small we
#     646     # ignore this problem here, for simplicity's sake.
#     647     extrema = relax_bounds(xmin, ymin, xmax, ymax)
#
# File ~\anaconda3\envs\PruebaInmobiliaria\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'total_bounds'

# %%
type(continental_usa_cities)
type(viviendas)
# Out:
# pandas.core.frame.DataFrame

# %%
viviendas = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.long, df.lat))

# %%
ax = gplt.polyplot(seattle)
gplt.pointplot(viviendas, ax=ax)
# Out:
# C:\Users\Cris\anaconda3\envs\PruebaInmobiliaria\lib\site-packages\geoplot\geoplot.py:885: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for subgeom in geom:
